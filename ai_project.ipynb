# %%
import sys
import time
from copy import deepcopy
from random import randint, shuffle

BOARD_WIDTH = 7
BOARD_HEIGHT = 6
AI_STRENGTH = 200
cellOptions = [" ", "Y", "R"]; # empty, Yellow symbol, Red symbol

CIRCLE_INVALID = -1
CIRCLE_EMPTY = 0
CIRCLE_YELLOW = 1
CIRCLE_RED = 2
CIRCLE_DRAW = 3
NO_WINNER = 4
COLORAMA = False
CLEARABLE = False
RUSH = True
emptyBoard = [[0 for x in range(BOARD_WIDTH)] for y in range(BOARD_HEIGHT)]
BX = BOARD_WIDTH - 1
BY = BOARD_HEIGHT - 1
ttmList = []
SMALL_BANNER = ''' _
/  _ ._ ._  _  __|_  |_|_
\_(_)| || |(/_(_ |_    |  '''

def Get(b, level, col):
    if col < 0 or col > BX or level < 0 or level > BY:
        return CIRCLE_INVALID
    return b[level][col]


def Set(b, level, col, value):
    b[level][col] = value


def ColIsFull(b, col):
    return (Get(b, BY, col) != CIRCLE_EMPTY)


def Drop(b, col, value):
    if (ColIsFull(b,col) == CIRCLE_INVALID):
        return 0
    for level in range(0,BOARD_HEIGHT):
        if Get(b, level, col) == CIRCLE_EMPTY:
            Set(b, level, col, value)
            break
    return 1


def printGameBoard(b):
    export = ""
    if CLEARABLE:
        os.system('cls||echo -e \\\\033c')
    if COLORAMA:
        export = export + colorama.Fore.YELLOW + SMALL_BANNER + colorama.Style.RESET_ALL + "\n"
    else:
        export = export + SMALL_BANNER + '\n'+ '\n' +'\n'
    for level in range(BY, -1, -1):
        export = export + str(level)
        for col in range(0, BOARD_WIDTH):
            color = Get(b, level, col)
            if COLORAMA:
                if color == CIRCLE_YELLOW:
                    export = export + colorama.Fore.YELLOW+"[Y]"+colorama.Style.RESET_ALL
                elif color == CIRCLE_RED:
                    export = export + colorama.Fore.RED+"[R]"+colorama.Style.RESET_ALL
                else:
                    export = export + "[ ]"
            else:
                export = export + "[" + str(cellOptions[color]) + "]"
        export = export + "\n"
    export = export + " "
    for col in range(0, BOARD_WIDTH):
        export = export + " " + str(col) + " "
    print(export)


def GetWinner(b):
    empty = 0
    sp = 0
    for level in range(BY, -1, -1):
        for col in range(0, BX):
            color = Get(b, level, col)
            if (color == CIRCLE_EMPTY):
                empty = empty + 1
                continue
            directory = [[1,0],[0,1],[1,1],[-1,1]]

            for d in range(0, 4):
                start_col = col
                start_level = level
                while(Get(b, start_level-directory[d][1], start_col-directory[d][0]) == color):
                    start_col = start_col - directory[d][0]
                    start_level = start_level - directory[d][1]

                count = 0
                while(Get(b, start_level, start_col) == color):
                    count = count + 1
                    start_col = start_col + directory[d][0]
                    start_level = start_level + directory[d][1]
                if (count >= 4):
                    return color
    if(empty <= BOARD_HEIGHT * BOARD_WIDTH):
        return CIRCLE_EMPTY
    return CIRCLE_DRAW


def RandomGame(b, tomove):
    for i in range(0, BOARD_HEIGHT * BOARD_WIDTH):
        potentialMoves = [x for x in range(0,BOARD_WIDTH)]
        shuffle(potentialMoves)
        for move in potentialMoves:
            if(not ColIsFull(b, move)):
                nextMove = move
                break
        if (Drop(b, nextMove, tomove)):
            if(tomove == CIRCLE_YELLOW):
                tomove = CIRCLE_RED
            else:
                tomove = CIRCLE_YELLOW
        winner = GetWinner(b)
        if (winner != CIRCLE_EMPTY):
            return winner
    return CIRCLE_DRAW


def SuggestMove(b, tomove, simulations=AI_STRENGTH):
    best = -1
    best_ratio = 0
    if COLORAMA:
        if tomove == CIRCLE_YELLOW:
            print(colorama.Fore.YELLOW + "YELLOW IS THINKING" + colorama.Style.RESET_ALL)
        elif tomove == CIRCLE_RED:
            print(colorama.Fore.RED + "RED IS THINKING" + colorama.Style.RESET_ALL)
    for move in range(0,BX+1):
        ttm = time.time()
        if (ColIsFull(b,move)):
            continue
        won = 0
        lost = 0
        draw = 0
        print_neutral = 1
        for j in range(0, simulations):
            copy = deepcopy(b)
            Drop(copy, move, tomove);
            if (GetWinner(copy) == tomove):
                return move
            if (tomove == CIRCLE_YELLOW):
                nextPlayer = CIRCLE_RED
            else:
                nextPlayer = CIRCLE_YELLOW
            winner = RandomGame(copy, nextPlayer)
            if (winner == CIRCLE_YELLOW or winner == CIRCLE_RED):
                if (winner == tomove):
                    won = won + 1
                else:
                    lost = lost + 1
            else:
                draw = draw + 1
            if j == AI_STRENGTH/2 and RUSH == True:
                ratio = float(won)/(lost+won+1);
                if(ratio+0.05 <= best_ratio and best != -1):
                    if COLORAMA:
                        print(colorama.Fore.RED + "X" + colorama.Style.RESET_ALL, end = " ")
                        print_neutral = 0
                    break
        ratio = float(won)/(lost+won+1);
        if(ratio > best_ratio or best == -1):
            best = move
            best_ratio = ratio
            if COLORAMA:
                print(colorama.Fore.GREEN + "$" + colorama.Style.RESET_ALL, end = " ")
                print_neutral = 0
        if COLORAMA and print_neutral == 1:
            print(colorama.Fore.YELLOW + "?" + colorama.Style.RESET_ALL, end = " ")
        ttmList.append(time.time() - ttm)
        print("Move", move, ":", round(ratio*100,1), "draws:", draw, "ttm:", round(ttmList[-1],1), "attm:", round(sum(ttmList)/len(ttmList),1))

    return best


def sim():
    board = deepcopy(emptyBoard)
    while(1):
        printGameBoard(board)
        if showPotentialWinner(board):  return
        Drop(board,SuggestMove(board, CIRCLE_RED, AI_STRENGTH), CIRCLE_RED)
        if showPotentialWinner(board):  return
        printGameBoard(board)
        Drop(board, SuggestMove(board, CIRCLE_YELLOW, AI_STRENGTH), CIRCLE_YELLOW)

def showPotentialWinner(board):
    winner = GetWinner(board)
    if winner != CIRCLE_EMPTY and winner != CIRCLE_DRAW:
        printGameBoard(board)
        if COLORAMA:
            if winner == CIRCLE_YELLOW:
                print(colorama.Fore.YELLOW+" winner: YELLOW" + colorama.Style.RESET_ALL)
            else:
                print(colorama.Fore.RED+" winner: RED" + colorama.Style.RESET_ALL)
            return True
        else:
            print("winner: ", winner)
            return True
    elif winner == CIRCLE_DRAW:
        printGameBoard(board)
        print("DRAW!")
    return False

if __name__== "__main__":


    if "--easy" in sys.argv:
        AI_STRENGTH = 250
    elif "--medium" in sys.argv or "--med" in sys.argv:
        AI_STRENGTH = 500
    elif "--hard" in sys.argv:
        AI_STRENGTH = 1000

    elif "--insane" in sys.argv:
        AI_STRENGTH = 2500

    elif "--master" in sys.argv:
        AI_STRENGTH = 5000

    elif "--demigod" in sys.argv:
        AI_STRENGTH = 10000

    elif "--god" in sys.argv:
        AI_STRENGTH = 100000

    if "--norush" in sys.argv:
        RUSH = False

    elif "--rush" in sys.argv:
        RUSH = True

    if "--pretty" in sys.argv:
        try:
            import colorama
            colorama.init()
            COLORAMA = 1
        except ImportError:
            print("You do not have COLORAMA installed. No colors for you :(")

    if "--clearable" in sys.argv:
        import os
        CLEARABLE = 1
    else:
        sim()
# Out:
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][ ][ ][ ][ ]
# 1[ ][ ][ ][ ][ ][ ][ ]
# 0[ ][ ][ ][ ][ ][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 56.2 draws: 0 ttm: 0.3 attm: 0.3
# Move 1 : 55.5 draws: 1 ttm: 0.2 attm: 0.3
# Move 2 : 62.7 draws: 0 ttm: 0.2 attm: 0.3
# Move 3 : 55.9 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 55.4 draws: 1 ttm: 0.1 attm: 0.2
# Move 5 : 50.0 draws: 2 ttm: 0.1 attm: 0.2
# Move 6 : 46.1 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][ ][ ][ ][ ]
# 1[ ][ ][ ][ ][ ][ ][ ]
# 0[ ][ ][R][ ][ ][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 41.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 49.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 43.1 draws: 0 ttm: 0.3 attm: 0.2
# Move 3 : 43.6 draws: 1 ttm: 0.3 attm: 0.2
# Move 4 : 40.2 draws: 0 ttm: 0.2 attm: 0.2
# Move 5 : 35.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 6 : 33.3 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][ ][ ][ ][ ]
# 1[ ][ ][ ][ ][ ][ ][ ]
# 0[ ][Y][R][ ][ ][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 52.0 draws: 1 ttm: 0.4 attm: 0.2
# Move 1 : 58.7 draws: 0 ttm: 0.4 attm: 0.2
# Move 2 : 58.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 3 : 59.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 4 : 52.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 5 : 58.8 draws: 2 ttm: 0.2 attm: 0.2
# Move 6 : 55.5 draws: 1 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][ ][ ][ ][ ]
# 1[ ][ ][ ][ ][ ][ ][ ]
# 0[ ][Y][R][R][ ][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 26.4 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 46.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 41.8 draws: 0 ttm: 0.3 attm: 0.2
# Move 3 : 35.3 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 52.3 draws: 2 ttm: 0.2 attm: 0.2
# Move 5 : 43.1 draws: 0 ttm: 0.1 attm: 0.2
# Move 6 : 32.4 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][ ][ ][ ][ ]
# 1[ ][ ][ ][ ][ ][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 49.5 draws: 1 ttm: 0.2 attm: 0.2
# Move 1 : 56.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 61.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 3 : 64.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 4 : 60.0 draws: 1 ttm: 0.2 attm: 0.2
# Move 5 : 47.1 draws: 0 ttm: 0.1 attm: 0.2
# Move 6 : 36.3 draws: 0 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][ ][ ][ ][ ]
# 1[ ][ ][ ][R][ ][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 32.3 draws: 0 ttm: 0.4 attm: 0.2
# Move 1 : 44.8 draws: 0 ttm: 0.3 attm: 0.2
# Move 2 : 36.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 3 : 47.8 draws: 0 ttm: 0.4 attm: 0.2
# Move 4 : 42.3 draws: 0 ttm: 0.4 attm: 0.2
# Move 5 : 19.8 draws: 1 ttm: 0.2 attm: 0.2
# Move 6 : 23.8 draws: 1 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][Y][ ][ ][ ]
# 1[ ][ ][ ][R][ ][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 53.2 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 52.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 61.8 draws: 2 ttm: 0.2 attm: 0.2
# Move 3 : 50.0 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 59.5 draws: 1 ttm: 0.2 attm: 0.2
# Move 5 : 45.1 draws: 0 ttm: 0.1 attm: 0.2
# Move 6 : 42.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][Y][ ][ ][ ]
# 1[ ][ ][R][R][ ][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 23.9 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 45.0 draws: 1 ttm: 0.2 attm: 0.2
# Move 2 : 36.4 draws: 3 ttm: 0.1 attm: 0.2
# Move 3 : 29.4 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 46.5 draws: 1 ttm: 0.2 attm: 0.2
# Move 5 : 34.3 draws: 0 ttm: 0.1 attm: 0.2
# Move 6 : 29.4 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][Y][ ][ ][ ]
# 1[ ][ ][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 43.8 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 57.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 60.2 draws: 0 ttm: 0.1 attm: 0.2
# Move 3 : 52.0 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 61.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 5 : 51.5 draws: 1 ttm: 0.1 attm: 0.2
# Move 6 : 38.2 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][ ][ ][ ][ ]
# 2[ ][ ][ ][Y][R][ ][ ]
# 1[ ][ ][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 31.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 48.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 45.8 draws: 0 ttm: 0.2 attm: 0.2
# Move 3 : 50.8 draws: 2 ttm: 0.2 attm: 0.2
# Move 4 : 35.3 draws: 0 ttm: 0.1 attm: 0.2
# Move 5 : 39.8 draws: 0 ttm: 0.2 attm: 0.2
# Move 6 : 39.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][Y][ ][ ][ ]
# 2[ ][ ][ ][Y][R][ ][ ]
# 1[ ][ ][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 46.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 59.7 draws: 0 ttm: 0.3 attm: 0.2
# Move 2 : 52.0 draws: 0 ttm: 0.1 attm: 0.2
# Move 3 : 50.0 draws: 0 ttm: 0.2 attm: 0.2
# Move 4 : 53.7 draws: 0 ttm: 0.3 attm: 0.2
# Move 5 : 50.5 draws: 1 ttm: 0.2 attm: 0.2
# Move 6 : 49.0 draws: 0 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][ ][ ][ ][ ]
# 3[ ][ ][ ][Y][ ][ ][ ]
# 2[ ][ ][ ][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 25.4 draws: 0 ttm: 0.2 attm: 0.2
# Move 1 : 37.8 draws: 0 ttm: 0.3 attm: 0.2
# Move 2 : 47.5 draws: 1 ttm: 0.2 attm: 0.2
# Move 3 : 52.2 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 46.1 draws: 0 ttm: 0.1 attm: 0.2
# Move 5 : 40.2 draws: 0 ttm: 0.1 attm: 0.2
# Move 6 : 35.3 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][ ][ ][ ][ ]
# 4[ ][ ][ ][Y][ ][ ][ ]
# 3[ ][ ][ ][Y][ ][ ][ ]
# 2[ ][ ][ ][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 41.3 draws: 0 ttm: 0.1 attm: 0.2
# Move 1 : 43.8 draws: 0 ttm: 0.1 attm: 0.2
# Move 2 : 42.3 draws: 0 ttm: 0.1 attm: 0.2
# Move 3 : 64.7 draws: 0 ttm: 0.2 attm: 0.2
# Move 4 : 47.1 draws: 0 ttm: 0.1 attm: 0.2
# Move 5 : 45.1 draws: 0 ttm: 0.1 attm: 0.2
# Move 6 : 36.3 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][ ][Y][ ][ ][ ]
# 3[ ][ ][ ][Y][ ][ ][ ]
# 2[ ][ ][ ][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 22.4 draws: 0 ttm: 0.1 attm: 0.2
# Move 1 : 35.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 2 : 39.4 draws: 3 ttm: 0.2 attm: 0.2
# Move 4 : 35.3 draws: 0 ttm: 0.2 attm: 0.2
# Move 5 : 30.7 draws: 1 ttm: 0.1 attm: 0.2
# Move 6 : 32.4 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][ ][Y][ ][ ][ ]
# 3[ ][ ][ ][Y][ ][ ][ ]
# 2[ ][ ][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 56.5 draws: 1 ttm: 0.2 attm: 0.2
# Move 1 : 64.0 draws: 1 ttm: 0.2 attm: 0.2
# Move 2 : 75.4 draws: 6 ttm: 0.3 attm: 0.2
# Move 4 : 61.6 draws: 3 ttm: 0.1 attm: 0.2
# Move 5 : 65.3 draws: 1 ttm: 0.1 attm: 0.2
# Move 6 : 52.9 draws: 0 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][ ][Y][ ][ ][ ]
# 3[ ][ ][R][Y][ ][ ][ ]
# 2[ ][ ][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 13.1 draws: 2 ttm: 0.2 attm: 0.2
# Move 1 : 35.2 draws: 5 ttm: 0.3 attm: 0.2
# Move 2 : 21.8 draws: 1 ttm: 0.1 attm: 0.2
# Move 4 : 33.2 draws: 2 ttm: 0.3 attm: 0.2
# Move 5 : 16.8 draws: 1 ttm: 0.1 attm: 0.2
# Move 6 : 19.2 draws: 3 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][ ][Y][ ][ ][ ]
# 3[ ][ ][R][Y][ ][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 62.2 draws: 5 ttm: 0.2 attm: 0.2
# Move 1 : 68.9 draws: 5 ttm: 0.3 attm: 0.2
# Move 2 : 72.7 draws: 3 ttm: 0.2 attm: 0.2
# Move 4 : 68.5 draws: 4 ttm: 0.2 attm: 0.2
# Move 5 : 61.6 draws: 3 ttm: 0.1 attm: 0.2
# Move 6 : 60.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][R][Y][ ][ ][ ]
# 3[ ][ ][R][Y][ ][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 25.0 draws: 1 ttm: 0.2 attm: 0.2
# Move 1 : 42.1 draws: 4 ttm: 0.3 attm: 0.2
# Move 2 : 36.6 draws: 1 ttm: 0.1 attm: 0.2
# Move 4 : 29.7 draws: 1 ttm: 0.1 attm: 0.2
# Move 5 : 28.7 draws: 1 ttm: 0.1 attm: 0.2
# Move 6 : 24.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][R][Y][ ][ ][ ]
# 3[ ][Y][R][Y][ ][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 56.9 draws: 4 ttm: 0.2 attm: 0.2
# Move 1 : 68.4 draws: 8 ttm: 0.3 attm: 0.2
# Move 2 : 62.6 draws: 6 ttm: 0.2 attm: 0.2
# Move 4 : 70.3 draws: 6 ttm: 0.2 attm: 0.2
# Move 5 : 62.2 draws: 4 ttm: 0.1 attm: 0.2
# Move 6 : 59.2 draws: 4 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][ ][R][Y][ ][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 23.1 draws: 6 ttm: 0.2 attm: 0.2
# Move 1 : 52.0 draws: 5 ttm: 0.2 attm: 0.2
# Move 2 : 40.8 draws: 4 ttm: 0.1 attm: 0.2
# Move 4 : 36.6 draws: 1 ttm: 0.1 attm: 0.2
# Move 5 : 34.0 draws: 5 ttm: 0.1 attm: 0.2
# Move 6 : 30.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][ ][ ][R][ ][ ][ ]
# 4[ ][Y][R][Y][ ][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 51.0 draws: 3 ttm: 0.2 attm: 0.2
# Move 1 : 85.2 draws: 5 ttm: 0.2 attm: 0.2
# Move 2 : 44.0 draws: 2 ttm: 0.1 attm: 0.2
# Move 4 : 61.5 draws: 6 ttm: 0.1 attm: 0.2
# Move 5 : 51.0 draws: 2 ttm: 0.1 attm: 0.2
# Move 6 : 44.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][ ][R][ ][ ][ ]
# 4[ ][Y][R][Y][ ][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 16.3 draws: 11 ttm: 0.2 attm: 0.2
# Move 2 : 17.8 draws: 10 ttm: 0.3 attm: 0.2
# Move 4 : 20.4 draws: 5 ttm: 0.3 attm: 0.2
# Move 5 : 11.2 draws: 4 ttm: 0.2 attm: 0.2
# Move 6 : 18.8 draws: 10 ttm: 0.4 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][ ][R][ ][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 77.6 draws: 5 ttm: 0.4 attm: 0.2
# Move 2 : 89.0 draws: 1 ttm: 0.3 attm: 0.2
# Move 4 : 81.6 draws: 4 ttm: 0.2 attm: 0.2
# Move 5 : 81.8 draws: 3 ttm: 0.2 attm: 0.2
# Move 6 : 82.0 draws: 2 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][ ][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 6.0 draws: 0 ttm: 0.1 attm: 0.2
# Move 4 : 24.9 draws: 8 ttm: 0.3 attm: 0.2
# Move 5 : 8.9 draws: 1 ttm: 0.1 attm: 0.2
# Move 6 : 8.9 draws: 1 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][ ]
#   0  1  2  3  4  5  6
# Move 0 : 63.8 draws: 5 ttm: 0.2 attm: 0.2
# Move 5 : 75.4 draws: 6 ttm: 0.2 attm: 0.2
# Move 6 : 77.0 draws: 5 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][ ][R]
#   0  1  2  3  4  5  6
# Move 0 : 22.4 draws: 5 ttm: 0.2 attm: 0.2
# Move 5 : 26.8 draws: 11 ttm: 0.3 attm: 0.2
# Move 6 : 21.0 draws: 2 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][ ][ ]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 67.0 draws: 10 ttm: 0.2 attm: 0.2
# Move 5 : 80.1 draws: 5 ttm: 0.2 attm: 0.2
# Move 6 : 73.5 draws: 4 ttm: 0.1 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][R][ ]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 18.1 draws: 8 ttm: 0.2 attm: 0.2
# Move 5 : 22.4 draws: 9 ttm: 0.2 attm: 0.2
# Move 6 : 25.4 draws: 8 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][ ]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 65.5 draws: 4 ttm: 0.2 attm: 0.2
# Move 5 : 73.8 draws: 10 ttm: 0.2 attm: 0.2
# Move 6 : 76.1 draws: 13 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][ ]
# 2[ ][Y][Y][Y][R][ ][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 20.7 draws: 8 ttm: 0.2 attm: 0.2
# Move 5 : 18.8 draws: 9 ttm: 0.2 attm: 0.2
# Move 6 : 27.0 draws: 23 ttm: 0.3 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][ ]
# 3[ ][Y][R][Y][R][ ][Y]
# 2[ ][Y][Y][Y][R][ ][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 68.4 draws: 5 ttm: 0.2 attm: 0.2
# Move 5 : 63.2 draws: 30 ttm: 0.3 attm: 0.2
# Move 6 : 76.2 draws: 20 ttm: 0.3 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][ ]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][ ][Y]
# 2[ ][Y][Y][Y][R][ ][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 19.9 draws: 10 ttm: 0.2 attm: 0.2
# Move 5 : 17.6 draws: 14 ttm: 0.2 attm: 0.2
# Move 6 : 21.6 draws: 25 ttm: 0.3 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][ ][Y]
# 2[ ][Y][Y][Y][R][ ][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 68.7 draws: 6 ttm: 0.1 attm: 0.2
# Move 5 : 74.4 draws: 33 ttm: 0.3 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][ ][Y]
# 2[ ][Y][Y][Y][R][R][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 0.0 draws: 0 ttm: 0.0 attm: 0.2
# Move 5 : 56.9 draws: 57 ttm: 0.5 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][Y][Y]
# 2[ ][Y][Y][Y][R][R][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[ ][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 45.8 draws: 81 ttm: 0.6 attm: 0.2
# Move 5 : 29.3 draws: 27 ttm: 0.2 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][Y][Y]
# 2[ ][Y][Y][Y][R][R][R]
# 1[ ][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 87.1 draws: 38 ttm: 0.3 attm: 0.2
# Move 5 : 0.0 draws: 57 ttm: 0.4 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][Y][Y]
# 2[ ][Y][Y][Y][R][R][R]
# 1[Y][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 36.7 draws: 92 ttm: 0.7 attm: 0.2
# Move 5 : 0.0 draws: 0 ttm: 0.0 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][ ][R]
# 3[ ][Y][R][Y][R][Y][Y]
# 2[R][Y][Y][Y][R][R][R]
# 1[Y][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 66.9 draws: 44 ttm: 0.5 attm: 0.2
# Move 5 : 68.7 draws: 134 ttm: 1.5 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][Y][R]
# 3[ ][Y][R][Y][R][Y][Y]
# 2[R][Y][Y][Y][R][R][R]
# 1[Y][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 39.4 draws: 46 ttm: 0.6 attm: 0.2
# Move 5 : 0.0 draws: 101 ttm: 1.0 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][ ][Y]
# 4[ ][Y][R][Y][Y][Y][R]
# 3[R][Y][R][Y][R][Y][Y]
# 2[R][Y][Y][Y][R][R][R]
# 1[Y][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# Move 0 : 0.0 draws: 86 ttm: 0.6 attm: 0.2
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][Y][Y]
# 4[ ][Y][R][Y][Y][Y][R]
# 3[R][Y][R][Y][R][Y][Y]
# 2[R][Y][Y][Y][R][R][R]
# 1[Y][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
#  _
# /  _ ._ ._  _  __|_  |_|_
# \_(_)| || |(/_(_ |_    |
#
#
# 5[ ][R][R][R][Y][Y][Y]
# 4[ ][Y][R][Y][Y][Y][R]
# 3[R][Y][R][Y][R][Y][Y]
# 2[R][Y][Y][Y][R][R][R]
# 1[Y][R][R][R][Y][R][Y]
# 0[R][Y][R][R][Y][Y][R]
#   0  1  2  3  4  5  6
# winner:  1
